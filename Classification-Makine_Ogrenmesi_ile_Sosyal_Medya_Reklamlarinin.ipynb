# %% [markdown]
# ### Sosyal medya reklamlarının sınıflandırılması tamamen hedef kitlenizin ürünü satın alıp almayacağını sınıflandırmak için reklamların analiz edilmesiyle ilgilidir.
# ### Pazarlamada veri bilimi için harika bir kullanım örneğidir .
# ### Hedef kitlenizi sınıflandırmak için sosyal medya reklamlarını nasıl analiz edeceğinizi öğrenmek istiyorsanız bu makale tam size göre.

# %%
#pip install pycaret

# %%
import pandas as pd

# %%
# Classification

# %%
df=pd.read_csv('https://raw.githubusercontent.com/amankharwal/Website-data/master/social.csv')

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['EstimatedSalary'].plot(kind='hist', bins=20, title='EstimatedSalary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='Age', y='EstimatedSalary', s=32, alpha=.8)
# ...

# %%
from pycaret.classification import*

# %%
setup(df,target='Purchased')
# Out:
# <style type="text/css">
# #T_b73d3_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b73d3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b73d3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b73d3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b73d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b73d3_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b73d3_row0_col1" class="data row0 col1" >7699</td>
#     </tr>
#     <tr>
#       <th id="T_b73d3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b73d3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b73d3_row1_col1" class="data row1 col1" >Purchased</td>
#     </tr>
#     <tr>
#       <th id="T_b73d3_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_30ce5 th {
#   text-align: left;
# }
# ...

# %%
best_model=create_model('ridge')
# Out:
# <style type="text/css">
# #T_4a2a4_row10_col0, #T_4a2a4_row10_col1, #T_4a2a4_row10_col2, #T_4a2a4_row10_col3, #T_4a2a4_row10_col4, #T_4a2a4_row10_col5, #T_4a2a4_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_4a2a4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a2a4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_4a2a4_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_4a2a4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_4a2a4_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_4a2a4_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_4a2a4_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_4a2a4_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
plot_model(best_model,plot='feature')
